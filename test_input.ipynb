# %%
import numpy as np
from utils import getFiles

fnames = getFiles("/home/ed/segmentation_work/miccai_2015_data/headHunted/Structures/")
mask = np.load("/home/ed/segmentation_work/miccai_2015_data/headHunted/Structures/" + fnames[0])
ct = np.load("/home/ed/segmentation_work/miccai_2015_data/headHunted/CTs/" + fnames[0])
print(mask.shape)
# Out:
# (56, 200, 200)

# %%
import matplotlib.pyplot as plt

plt.hist(mask.flatten(), bins=11)
plt.show()

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(ct[28])
ax[1].imshow(mask[28])
plt.show()
